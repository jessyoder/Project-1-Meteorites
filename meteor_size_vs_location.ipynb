# %%
# Conclusions: There doesn't seem to be any clear pattern connecting any particular latitude or longitude to be more likely
# to get struck by a certain size of meteorite. Especially when looking between the Year Range Groups, there doesn't seem 
# to be a pattern. This disappoints my hopes that there is a place to go to find a huge meteorite. :)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import gkey

# %%
# Read Meteorite_Landings.csv file
meteorite_landings_df = pd.read_csv('Meteorite_Landings.csv')
meteorite_landings_df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)
# 5  01/01/1919 12:00:00 AM  32.10000   71.80000          (32.1, 71.8)
# 6  01/01/1949 12:00:00 AM  44.83333   95.16667  (44.83333, 95.16667)
# 7  01/01/1814 12:00:00 AM  44.21667    0.61667   (44.21667, 0.61667)
# 8  01/01/1930 12:00:00 AM -31.60000  -65.23333    (-31.6, -65.23333)
# 9  01/01/1920 12:00:00 AM -30.86667  -64.55000   (-30.86667, -64.55)

# %%
# Count the row number of the dataset
len(meteorite_landings_df)
# Out:
# 45716

# %%
# Modify the dataframe to grab "year" - split with " " space
year_split = meteorite_landings_df["year"].str.split(" ", n = 1, expand = True) 
year_split.head()
# Out:
#             0            1
# 0  01/01/1880  12:00:00 AM
# 1  01/01/1951  12:00:00 AM
# 2  01/01/1952  12:00:00 AM
# 3  01/01/1976  12:00:00 AM
# 4  01/01/1902  12:00:00 AM

# %%
# Modify the year_split to grab only "year" data - split with "/"
date_split = year_split[0].str.split("/", n = 2, expand = True) 
date_split.head()
# Out:
#     0   1     2
# 0  01  01  1880
# 1  01  01  1951
# 2  01  01  1952
# 3  01  01  1976
# 4  01  01  1902

# %%
# Name the date_split[2] to "Year", and add the data column to meteorite_landings dataframe
meteorite_landings_df["Year"]= date_split[2]
meteorite_landings_df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation  Year
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)  1880
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)  1951
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)  1952
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)  1976
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)  1902

# %%
# Delete 'year' column and use 'Year' column for data analyses
del meteorite_landings_df["year"]
meteorite_landings_df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    reclat    reclong  \
# 0    Aachen    1    Valid           L5      21.0  Fell  50.77500    6.08333
# 1    Aarhus    2    Valid           H6     720.0  Fell  56.18333   10.23333
# 2      Abee    6    Valid          EH4  107000.0  Fell  54.21667 -113.00000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  16.88333  -99.90000
# 4   Achiras  370    Valid           L6     780.0  Fell -33.16667  -64.95000
#
#             GeoLocation  Year
# 0     (50.775, 6.08333)  1880
# 1  (56.18333, 10.23333)  1951
# 2    (54.21667, -113.0)  1952
# 3     (16.88333, -99.9)  1976
# 4   (-33.16667, -64.95)  1902

# %%
# Sort the dataset with Year
sort_meteorite_landings_df = meteorite_landings_df.sort_values(["Year"], ascending=True)
sort_meteorite_landings_df.head(10)
# Out:
#                    name     id nametype      recclass    mass (g)   fall  \
# 704              Nogata  16988    Valid            L6       472.0   Fell
# 679               Narni  16914    Valid    Stone-uncl         NaN   Fell
# 278             Elbogen   7823    Valid     Iron, IID    107000.0   Fell
# 856    Rivolta de Bassi  22614    Valid    Stone-uncl       103.3   Fell
# 283           Ensisheim  10039    Valid           LL6    127000.0   Fell
# 1043          Valdinoce  24146    Valid    Stone-uncl         NaN   Fell
# 730        Oliva-Gandia  18012    Valid    Stone-uncl         NaN   Fell
# 5365    Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 174       Castrovillari   5295    Valid    Stone-uncl     15000.0   Fell
# 26174            Morito  16745    Valid   Iron, IIIAB  10100000.0  Found
#
#          reclat    reclong             GeoLocation  Year
# 704    33.72500  130.75000        (33.725, 130.75)  0860
# 679    42.51667   12.51667    (42.51667, 12.51667)  0920
# 278    50.18333   12.73333    (50.18333, 12.73333)  1399
# 856    45.48333    9.51667     (45.48333, 9.51667)  1490
# 283    47.86667    7.35000        (47.86667, 7.35)  1491
# 1043   44.06667   12.10000        (44.06667, 12.1)  1495
# 730    39.00000   -0.03333        (39.0, -0.03333)  1519
# 5365  -27.46667  -60.58333  (-27.46667, -60.58333)  1575
# 174    39.80000   16.20000            (39.8, 16.2)  1583
# 26174  27.05000 -105.43333     (27.05, -105.43333)  1600

# %%
# Set up a bin to create graphs based on Year
# But first, check data types
# sort_meteorite_landings_df.dtypes

# %%
# Change Year datatypes to integer
sort_meteorite_landings_df["Year"] = pd.to_numeric(sort_meteorite_landings_df["Year"])
sort_meteorite_landings_df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# Year           float64
# dtype: object

# %%
# Drop missing data row
clean_meteorite_landings_df = sort_meteorite_landings_df.dropna(how="any")

# %%
# Set up a new data frame for Data Analyses
meteorite_map_df = clean_meteorite_landings_df[['name', 'id', 'mass (g)', 'reclat', 'reclong', 'Year']]
meteorite_map_df.dtypes
# Out:
# name         object
# id            int64
# mass (g)    float64
# reclat      float64
# reclong     float64
# Year        float64
# dtype: object

# %%
# Clean dataframe by dropping any N/A values
clean_meteorite_map = meteorite_map_df.dropna(how='any')
clean_meteorite_map
# Out:
#                         name     id    mass (g)    reclat    reclong    Year
# 704                   Nogata  16988       472.0  33.72500  130.75000   860.0
# 278                  Elbogen   7823    107000.0  50.18333   12.73333  1399.0
# 856         Rivolta de Bassi  22614       103.3  45.48333    9.51667  1490.0
# 283                Ensisheim  10039    127000.0  47.86667    7.35000  1491.0
# 5365         Campo del Cielo   5247  50000000.0 -27.46667  -60.58333  1575.0
# ...                      ...    ...         ...       ...        ...     ...
# 30775  Northwest Africa 7856  57421       517.0   0.00000    0.00000  2013.0
# 30774  Northwest Africa 7855  57420       916.0   0.00000    0.00000  2013.0
# 30762  Northwest Africa 7812  57258        46.2   0.00000    0.00000  2013.0
# 30730  Northwest Africa 7755  57166        30.0   0.00000    0.00000  2013.0
# 30682  Northwest Africa 7701  57150        55.0   0.00000    0.00000  2101.0
#
# [38115 rows x 6 columns]

# %%
# Create a new data frame for the meteor sightings map
meteor_df = meteorite_map_df[['mass (g)', 'reclat', 'reclong', 'Year']]

# Create a data frame that eliminates rows with values of 0
meteor_df = meteor_df.loc[meteor_df['mass (g)'] > 0]
meteor_df
# Out:
#          mass (g)    reclat    reclong    Year
# 704         472.0  33.72500  130.75000   860.0
# 278      107000.0  50.18333   12.73333  1399.0
# 856         103.3  45.48333    9.51667  1490.0
# 283      127000.0  47.86667    7.35000  1491.0
# 5365   50000000.0 -27.46667  -60.58333  1575.0
# ...           ...       ...        ...     ...
# 30775       517.0   0.00000    0.00000  2013.0
# 30774       916.0   0.00000    0.00000  2013.0
# 30762        46.2   0.00000    0.00000  2013.0
# 30730        30.0   0.00000    0.00000  2013.0
# 30682        55.0   0.00000    0.00000  2101.0
#
# [38096 rows x 4 columns]

# %%
x_axis = meteor_df['reclat']
y_axis = meteor_df['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Latitude: Total')
plt.xlabel('Latitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
x_axis = meteor_df['reclong']
y_axis = meteor_df['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Longitude: Total')
plt.xlabel('Longitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
# Set up bins for Years
year_bins = [0, 999.999, 1699.999, 1799.999, 1899.999, 1999.999, 2020]
group_names = ["<1000", "1000-1699", "1700-1799", "1800-1899", "1900-1999", "2000-2020"]

# Add a new column named Year Ramge amd binnning based off the range
meteor_df["Year Range"] = pd.cut(meteor_df["Year"], year_bins, labels=group_names)
del meteor_df["Year"]
meteor_df
# Out:
#          mass (g)    reclat    reclong Year Range
# 704         472.0  33.72500  130.75000      <1000
# 278      107000.0  50.18333   12.73333  1000-1699
# 856         103.3  45.48333    9.51667  1000-1699
# 283      127000.0  47.86667    7.35000  1000-1699
# 5365   50000000.0 -27.46667  -60.58333  1000-1699
# ...           ...       ...        ...        ...
# 30775       517.0   0.00000    0.00000  2000-2020
# 30774       916.0   0.00000    0.00000  2000-2020
# 30762        46.2   0.00000    0.00000  2000-2020
# 30730        30.0   0.00000    0.00000  2000-2020
# 30682        55.0   0.00000    0.00000        NaN
#
# [38096 rows x 4 columns]

# %%
# Check to see how many meteor sightings there are in each bin
meteor_count = meteor_df["Year Range"]
meteor_count.value_counts()
# Out:
# 1900-1999    24003
# 2000-2020    13386
# 1800-1899      659
# 1700-1799       32
# 1000-1699       14
# <1000            1
# Name: Year Range, dtype: int64

# %%
meteor_size_2000s = meteor_df.loc[meteor_df["Year Range"] == "2000-2020", :]

x_axis = meteor_size_2000s['reclat']
y_axis = meteor_size_2000s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Latitude 2000s')
plt.xlabel('Latitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
meteor_size_1900s = meteor_df.loc[meteor_df["Year Range"] == "1900-1999", :]

x_axis = meteor_size_1900s['reclat']
y_axis = meteor_size_1900s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Latitude 1900s')
plt.xlabel('Latitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
meteor_size_1800s = meteor_df.loc[meteor_df["Year Range"] == "1800-1899", :]

x_axis = meteor_size_1800s['reclat']
y_axis = meteor_size_1800s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Latitude 1800s')
plt.xlabel('Latitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
meteor_size_2000s = meteor_df.loc[meteor_df["Year Range"] == "2000-2020", :]

x_axis = meteor_size_2000s['reclong']
y_axis = meteor_size_2000s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Longitude 2000s')
plt.xlabel('Longitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
meteor_size_1900s = meteor_df.loc[meteor_df["Year Range"] == "1900-1999", :]

x_axis = meteor_size_1900s['reclong']
y_axis = meteor_size_1900s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Longitude 1900s')
plt.xlabel('Longitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')

# %%
meteor_size_1800s = meteor_df.loc[meteor_df["Year Range"] == "1800-1899", :]

x_axis = meteor_size_1800s['reclong']
y_axis = meteor_size_1800s['mass (g)']

plt.bar(x_axis, y_axis)
plt.title('Meteor Size vs Longitude 1800s')
plt.xlabel('Longitude')
plt.ylabel('Meteorite Mass (g)')
# Out:
# Text(0, 0.5, 'Meteorite Mass (g)')
